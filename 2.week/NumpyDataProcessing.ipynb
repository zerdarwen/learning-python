# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5*np.pi, 0.1)
y = np.sin(x) 

a=np.arange(0, 5*np.pi, 0.1)
b=np.cos(a)

normalized_x= x/np.sqrt(np.sum(x**2))
normalized_y= y/np.sqrt(np.sum(y**2))
#print("Normalized x :", normalized_x, '\n'
      #"Normalized y :", normalized_y)
normalized_a= a/np.sqrt(np.sum(a**2))
normalized_b= b/np.sqrt(np.sum(b**2))
#print("Normalized a :", normalized_a, '\n'
      #"Normalized b :", normalized_b)

plt.plot(x, y, color='blue')
plt.plot(a, b, color='red')
plt.show()

# %%
import numpy as np
from numpy import random 
import matplotlib.pyplot as plt

arr=[2,4,6,8,10]
r=random.choice(arr, p=[0.2, 0.1, 0.2, 0.3, 0.2 ], size=(30))

#magnitude= np.linalg.norm(r)
#normalized_r=r/magnitude
#plt.plot(normalized_r,  color="pink")
#print(normalized_r)

plt.plot(r, color="pink")
plt.show()
